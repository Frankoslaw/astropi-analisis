# %%
# %pip install numpy
# %pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 MB 47.0 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !wget https://projects-static.raspberrypi.org/projects/astropi-ndvi/2cc9d1033d9c4f05388632e7912a4bb5531b3d94/en/images/park.png
# Out:
# --2023-06-19 11:32:34--  https://projects-static.raspberrypi.org/projects/astropi-ndvi/2cc9d1033d9c4f05388632e7912a4bb5531b3d94/en/images/park.png
# Resolving projects-static.raspberrypi.org (projects-static.raspberrypi.org)... 104.22.0.43, 172.67.36.98, 104.22.1.43, ...
# Connecting to projects-static.raspberrypi.org (projects-static.raspberrypi.org)|104.22.0.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5108381 (4.9M)
# Saving to: ‘park.png’
#
# park.png            100%[===================>]   4.87M  --.-KB/s    in 0.04s
#
# 2023-06-19 11:32:34 (113 MB/s) - ‘park.png’ saved [5108381/5108381]

# %%
# !wget https://projects-static.raspberrypi.org/projects/astropi-ndvi/b78579698edb143add0b9f9e84f99fe43f13c2b8/en/images/fastiecm.py
# Out:
# --2023-06-19 11:32:43--  https://projects-static.raspberrypi.org/projects/astropi-ndvi/b78579698edb143add0b9f9e84f99fe43f13c2b8/en/images/fastiecm.py
# Resolving projects-static.raspberrypi.org (projects-static.raspberrypi.org)... 104.22.1.43, 104.22.0.43, 172.67.36.98, ...
# Connecting to projects-static.raspberrypi.org (projects-static.raspberrypi.org)|104.22.1.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6983 (6.8K)
# Saving to: ‘fastiecm.py’
#
# fastiecm.py         100%[===================>]   6.82K  --.-KB/s    in 0s
#
# 2023-06-19 11:32:44 (91.2 MB/s) - ‘fastiecm.py’ saved [6983/6983]

# %%
# !wget --user-agent Mozilla/5.0 'https://download.wetransfer.com/eugv/db98fb2f54430f22c96c708da94187d020230524200725/d54e6a38910296c4047888dc76b4434654b3a34f/leniwce_run2.zip?cf=y&token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6ImRlZmF1bHQifQ.eyJleHAiOjE2ODcxNzUwMDMsImlhdCI6MTY4NzE3NDQwMywiZG93bmxvYWRfaWQiOiIwYzI3YTNmMS04NzAyLTRhOWQtOGM3Ni1mMzZkOGVhZTQwNDYiLCJzdG9yYWdlX3NlcnZpY2UiOiJzdG9ybSJ9.03Z2wVn7XI7aY1Mtat-PvLUFWBNmRvWGsoHCpW6YpdU' -O leniwce_run2.zip
# Out:
# --2023-06-19 11:33:43--  https://download.wetransfer.com/eugv/db98fb2f54430f22c96c708da94187d020230524200725/d54e6a38910296c4047888dc76b4434654b3a34f/leniwce_run2.zip?cf=y&token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCIsImtpZCI6ImRlZmF1bHQifQ.eyJleHAiOjE2ODcxNzUwMDMsImlhdCI6MTY4NzE3NDQwMywiZG93bmxvYWRfaWQiOiIwYzI3YTNmMS04NzAyLTRhOWQtOGM3Ni1mMzZkOGVhZTQwNDYiLCJzdG9yYWdlX3NlcnZpY2UiOiJzdG9ybSJ9.03Z2wVn7XI7aY1Mtat-PvLUFWBNmRvWGsoHCpW6YpdU
# Resolving download.wetransfer.com (download.wetransfer.com)... 18.66.112.4, 18.66.112.59, 18.66.112.58, ...
# Connecting to download.wetransfer.com (download.wetransfer.com)|18.66.112.4|:443... connected.
# HTTP request sent, awaiting response...
# 200 OK
# Length: 1091247485 (1.0G) [binary/octet-stream]
# Saving to: ‘leniwce_run2.zip’
#
# leniwce_run2.zip    100%[===================>]   1.02G  23.7MB/s    in 43s
#
# 2023-06-19 11:34:26 (23.9 MB/s) - ‘leniwce_run2.zip’ saved [1091247485/1091247485]

# %%
# !unzip leniwce_run2.zip
# Out:
# Archive:  leniwce_run2.zip
#   inflating: leniwce_run2/data.csv
#   inflating: leniwce_run2/events.log
#   inflating: leniwce_run2/files.txt
#   inflating: leniwce_run2/labels.txt
#   inflating: leniwce_run2/main.py
#   inflating: leniwce_run2/model_edgetpu.tflite
#   inflating: leniwce_run2/output.log
#   inflating: leniwce_run2/photo_001.jpg
#   inflating: leniwce_run2/photo_002.jpg
#   inflating: leniwce_run2/photo_003.jpg
#   inflating: leniwce_run2/photo_004.jpg
#   inflating: leniwce_run2/photo_005.jpg
#   inflating: leniwce_run2/photo_006.jpg
#   inflating: leniwce_run2/photo_007.jpg
#   inflating: leniwce_run2/photo_008.jpg
#   inflating: leniwce_run2/photo_009.jpg
#   inflating: leniwce_run2/photo_010.jpg
#   inflating: leniwce_run2/photo_011.jpg
#   inflating: leniwce_run2/photo_012.jpg
#   inflating: leniwce_run2/photo_013.jpg
#   inflating: leniwce_run2/photo_014.jpg
#   inflating: leniwce_run2/photo_015.jpg
#   inflating: leniwce_run2/photo_016.jpg
# ...

# %%
# !mkdir leniwce_run2/photos/
# !mv leniwce_run2/photo_* leniwce_run2/photos/
